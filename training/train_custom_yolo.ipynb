# %% [markdown]
# # 🚧 Train Custom YOLOv8 Model for Road Damage Detection
#
# This notebook trains YOLOv8m on your custom pothole/crack dataset.
#
# ## Steps:
# 1. Install dependencies
# 2. Prepare dataset folder
# 3. Train YOLOv8
# 4. Export best model

# %%
# !pip install ultralytics roboflow
from ultralytics import YOLO
import os

# %%
model = YOLO('yolov8m.pt')  # pretrained model
data_path = 'data.yaml'     # config for your dataset

results = model.train(
    data=data_path,
    epochs=50,
    imgsz=640,
    batch=8,
    name='road_damage_model'
)

print('Training complete!')
